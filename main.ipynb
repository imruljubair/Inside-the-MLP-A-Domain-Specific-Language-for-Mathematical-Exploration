# %% [markdown]
# <a href="https://colab.research.google.com/github/imruljubair/Inside-the-MLP-A-Domain-Specific-Language-for-Mathematical-Exploration/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Make sure that your Colab notebook editor is in **"Light mode"**.
# If not, you can change it from setting (upper right button)

# %%
# download script to import
# !gdown --fuzzy 'https://drive.google.com/file/d/19hdldGF3wmJDAdP-4AYUQYQg25v64cuZ/view?usp=sharing'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=19hdldGF3wmJDAdP-4AYUQYQg25v64cuZ
# From (redirected): https://drive.google.com/uc?id=19hdldGF3wmJDAdP-4AYUQYQg25v64cuZ&confirm=t&uuid=84a51ec7-3626-4b6a-9968-c57fd8cb0700
# To: /content/aibyhand.py
# 100% 28.3k/28.3k [00:00<00:00, 62.7MB/s]

# %%
from aibyhand import *

# %%
# %mlp_byhand y = 5 | 3 -> 6 -> 7 -> 8 -> 7 -> 6 -> 3

# %%
reveal(y)
